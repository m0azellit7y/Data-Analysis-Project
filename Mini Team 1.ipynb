# %% [markdown]
# # Project 2
# # Mini Team 1

# %%
import pandas as pd
import numpy as np
import hashlib

# %% [markdown]
# # TASK 1: Load Dataset

# %%
# TASK 1: Load Dataset

df = pd.read_csv('/content/diabetic_data (1).csv')
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %% [markdown]
# # TASK 2: Handle Sensitive Data (Anonymization)

# %%
# TASK 2: Anonymize Sensitive Healthcare Data

def hash_id(x):
    return hashlib.sha256(str(x).encode()).hexdigest()

df['anonymous_patient_id'] = df['patient_nbr'].apply(hash_id)

df.drop(['patient_nbr', 'encounter_id'], axis=1, inplace=True)

# %% [markdown]
# # TASK 3: Merge Multiple Data Sources

# %%
# TASK 3: Merge Mapping Tables

ids = pd.read_csv('/content/IDS_mapping.csv')

# Convert the 'admission_type_id' column in df to string type to match 'ids' DataFrame
df['admission_type_id'] = df['admission_type_id'].astype(str)

df = df.merge(ids, on='admission_type_id', how='left')
df.rename(columns={'description': 'admission_type'}, inplace=True)

# %% [markdown]
# # TASK 4: Handle Missing Values

# %%
# TASK 4: Handle Missing Values

df.replace('?', np.nan, inplace=True)

missing_ratio = df.isna().mean()
df.drop(missing_ratio[missing_ratio > 0.5].index, axis=1, inplace=True)

cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    # Convert column to string type to ensure consistent data for mode calculation
    temp_series = df[col].astype(str)

    # Calculate the mode. Handle potential empty mode result explicitly.
    modes = temp_series.mode()
    if not modes.empty:
        # Access the first mode value from the Series
        mode_val = modes.iloc[0]
    else:
        # Fallback for columns where mode cannot be determined (e.g., all values are NaNs)
        # Using a generic placeholder 'Unknown' for such cases.
        mode_val = 'Unknown'

    df[col] = df[col].fillna(mode_val)

num_cols = df.select_dtypes(include='number').columns
for col in num_cols:
    # Assign the result back to the column instead of using inplace=True
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# # TASK 5: Handle Outliers

# %%
# TASK 5: Handle Outliers using IQR

def iqr_filter(data, col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return data[(data[col] >= lower) & (data[col] <= upper)]

for col in ['num_lab_procedures', 'num_medications', 'time_in_hospital']:
    df = iqr_filter(df, col)

# %% [markdown]
# # TASK 6: Data Quality Assessment

# %%
# TASK 6: Data Quality Assessment Report

data_quality = pd.DataFrame({
    'Column': df.columns,
    'Data Type': df.dtypes.astype(str),
    'Missing %': df.isna().mean() * 100,
    'Unique Values': df.nunique()
})

data_quality
# Out:
#                                             Column Data Type  Missing %  \
# race                                          race    object        0.0
# gender                                      gender    object        0.0
# age                                            age    object        0.0
# admission_type_id                admission_type_id    object        0.0
# discharge_disposition_id  discharge_disposition_id     int64        0.0
# admission_source_id            admission_source_id     int64        0.0
# time_in_hospital                  time_in_hospital     int64        0.0
# payer_code                              payer_code    object        0.0
# medical_specialty                medical_specialty    object        0.0
# num_lab_procedures              num_lab_procedures     int64        0.0
# num_procedures                      num_procedures     int64        0.0
# num_medications                    num_medications     int64        0.0
# number_outpatient                number_outpatient     int64        0.0
# number_emergency                  number_emergency     int64        0.0
# number_inpatient                  number_inpatient     int64        0.0
# diag_1                                      diag_1    object        0.0
# diag_2                                      diag_2    object        0.0
# diag_3                                      diag_3    object        0.0
# number_diagnoses                  number_diagnoses     int64        0.0
# metformin                                metformin    object        0.0
# repaglinide                            repaglinide    object        0.0
# nateglinide                            nateglinide    object        0.0
# chlorpropamide                      chlorpropamide    object        0.0
# glimepiride                            glimepiride    object        0.0
# acetohexamide                        acetohexamide    object        0.0
# glipizide                                glipizide    object        0.0
# glyburide                                glyburide    object        0.0
# tolbutamide                            tolbutamide    object        0.0
# pioglitazone                          pioglitazone    object        0.0
# rosiglitazone                        rosiglitazone    object        0.0
# acarbose                                  acarbose    object        0.0
# miglitol                                  miglitol    object        0.0
# troglitazone                          troglitazone    object        0.0
# tolazamide                              tolazamide    object        0.0
# examide                                    examide    object        0.0
# citoglipton                            citoglipton    object        0.0
# insulin                                    insulin    object        0.0
# glyburide-metformin            glyburide-metformin    object        0.0
# glipizide-metformin            glipizide-metformin    object        0.0
# glimepiride-pioglitazone  glimepiride-pioglitazone    object        0.0
# metformin-rosiglitazone    metformin-rosiglitazone    object        0.0
# metformin-pioglitazone      metformin-pioglitazone    object        0.0
# change                                      change    object        0.0
# diabetesMed                            diabetesMed    object        0.0
# readmitted                              readmitted    object        0.0
# anonymous_patient_id          anonymous_patient_id    object        0.0
# admission_type                      admission_type    object        0.0
# admission_type                      admission_type    object        0.0
#
#                           Unique Values
# race                                  5
# gender                                3
# age                                  10
# admission_type_id                     8
# discharge_disposition_id             26
# admission_source_id                  17
# time_in_hospital                     12
# payer_code                           16
# medical_specialty                    72
# num_lab_procedures                   96
# num_procedures                        7
# num_medications                      35
# number_outpatient                    39
# number_emergency                     33
# number_inpatient                     20
# diag_1                              714
# diag_2                              745
# diag_3                              785
# number_diagnoses                     16
# metformin                             4
# repaglinide                           4
# nateglinide                           4
# chlorpropamide                        4
# glimepiride                           4
# acetohexamide                         1
# glipizide                             4
# glyburide                             4
# tolbutamide                           2
# pioglitazone                          4
# rosiglitazone                         4
# acarbose                              4
# miglitol                              4
# troglitazone                          2
# tolazamide                            3
# examide                               1
# citoglipton                           1
# insulin                               4
# glyburide-metformin                   4
# glipizide-metformin                   2
# glimepiride-pioglitazone              2
# metformin-rosiglitazone               2
# metformin-pioglitazone                2
# change                                2
# diabetesMed                           2
# readmitted                            3
# anonymous_patient_id              68926
# admission_type                       23
# admission_type                       23

# %% [markdown]
# # TASK 7: Export Clean Dataset

# %%
# TASK 7: Export Final Dataset

df.to_csv('clean_anonymized_readmission_data.csv', index=False)
